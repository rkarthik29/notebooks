# %%
import json
import java.io
import random
from org.apache.commons.io import IOUtils
from java.nio.charset import StandardCharsets
from org.apache.nifi.processor.io import InputStreamCallback,StreamCallback
from java.lang import System as javasystem
from java.io import BufferedReader,InputStreamReader

class PyStreamCallback(InputStreamCallback):
    def __init__(self):
        self.schema={}
        pass
    def process(self,inputStream):
        reader = BufferedReader(InputStreamReader(inputStream))
        while True:
            line = reader.readLine()
            if line is None:
                break
            jsonObj = json.loads(line)
            component = jsonObj["cwbtool__ComponentName__c"]
            compParent=jsonObj["cwbtool__Parent__c"]
            compType=jsonObj["cwbtool__Type__c"]
            if(compParent):
                if(compParent not in self.schema):
                    self.schema[compParent]=[]
                data = (component,compType)
                self.schema[compParent].append(data)
                #print (json.dumps(schema))
            else:
                if(component not in self.schema):
                    self.schema[component]=[]
class OutStreamCallback(StreamCallback):
    def __init__(self,tableName,columns):
        self.tableName=tableName
        self.columns=columns
        pass
    def process(self,inputStream,outputStream):
        sqlStr= "create table "+self.tableName+"("
        columnObj=[]
        for column in self.columns:
            columnObj.append(column[0]+" "+column[1])
        sqlStr=sqlStr+" "+ ",".join(columnObj)+" )"
        outputStream.write(sqlStr)
    
flowFile = session.get()
if (flowFile != None):
    callback = PyStreamCallback()
    session.read(flowFile,callback)
    session.putAttribute(flowFile,"schema",json.dumps(callback.schema))
    for key in callback.schema:
        flowFile1=session.create(flowFile)
        wCallBack= OutStreamCallback(key,callback.schema[key])
        flowFile1 = session.write(flowFile1,wCallBack)
        session.transfer(flowFile1, REL_SUCCESS)
    #session.transfer(flowFile, REL_SUCCESS)
    session.remove(flowFile)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-7a9d2ddf8191> in <module>()
#       1 import json
# ----> 2 import java.io
#       3 import random
#       4 from org.apache.commons.io import IOUtils
#       5 from java.nio.charset import StandardCharsets
#
# ModuleNotFoundError: No module named 'java'

# %%
import json
import java.io
import random
from org.apache.commons.io import IOUtils
from java.nio.charset import StandardCharsets
from org.apache.nifi.processor.io import StreamCallback
from java.lang import System as javasystem
from java.io import BufferedReader,InputStreamReader

class PyStreamCallback(StreamCallback):
  def __init__(self,keyField):
    self.key=keyField
    pass
  def process(self,inputStream,outputStream):
    outputStream.write("key;value\n")
    reader = BufferedReader(InputStreamReader(inputStream))
    while True:
        line = reader.readLine()
        if line is None:
            break
        obj = json.loads(line)
        outputStream.write(obj[self.key]+";"+line.replace(";","\;")+"\n")
flowFile = session.get()
if (flowFile != None):
    keyField = flowFile.getAttribute("keyField")
    callback = PyStreamCallback(keyField)
    flowFile = session.write(flowFile,callback)
    session.transfer(flowFile, REL_SUCCESS)

# %%
from datetime import datetime
def date_range(start, end, intv):
    startTime = datetime.strptime(start.split(".")[0],"%Y-%m-%d %H:%M:%S")
    endTime = datetime.strptime(end.split(".")[0],"%Y-%m-%d %H:%M:%S")
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append((startTime + diff * i).strftime("%Y-%m-%d %H:%M:%S"))
    timeStamps=[start]+timeStamps[1:-1]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses

def float_range(start, end, intv):
    startTime = float(start)
    endTime = float(end)
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append((startTime + diff * i))
    timeStamps=[start]+timeStamps[1:-1]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses

def int_range(start, end, intv):
    startTime = int(start)
    endTime = int(end)
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append(int((startTime + diff * i)))
    timeStamps=[start]+timeStamps[1:-1]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses

int_range(1,100,6)
# Out:
# [(1, 17), (17, 34), (34, 50), (50, 67), (67, 100)]

# %%
#whereClause="(AUD_LSUP_TS > '2018-06-01 00:00:01.00000') AND AUD_LSUP_TS <= '2018-08-30 14:46:07.725477'"
import json
from datetime import datetime
def date_range(start, end, intv):
    startTime = datetime.strptime(start.split(".")[0],"%Y-%m-%d %H:%M:%S")
    endTime = datetime.strptime(end.split(".")[0],"%Y-%m-%d %H:%M:%S")
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append((startTime + diff * i).strftime("%Y-%m-%d %H:%M:%S"))
    print(timeStamps)
    timeStamps=[start]+timeStamps[1:]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses

def float_range(start, end, intv):
    startTime = float(start)
    endTime = float(end)
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append((startTime + diff * i))
    timeStamps=[start]+timeStamps[1:-1]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses

def int_range(start, end, intv):
    startTime = int(start)
    endTime = int(end)
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append(int((startTime + diff * i)))
    timeStamps=[start]+timeStamps[1:-1]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses


jsonObj= json.loads('{"MAX_ID": "2008-04-21 00:00:00", "MIN_ID": "2001-01-13 00:00:00"}')
max_id=jsonObj["MAX_ID"]
min_id=jsonObj["MIN_ID"]
whereClauses=date_range(min_id,max_id,2)
for clause in whereClauses:
    print(str(clause[0])+","+str(clause[1]))
# Out:
# ['2001-01-13 00:00:00', '2004-09-01 12:00:00']
# 2001-01-13 00:00:00,2004-09-01 12:00:00
# 2004-09-01 12:00:00,2008-04-21 00:00:00

# %%
import json
import java.io
import random
from org.apache.commons.io import IOUtils
from java.nio.charset import StandardCharsets
from org.apache.nifi.processor.io import InputStreamCallback
from datetime import datetime

def date_range(start, end, intv):
    startTime = datetime.strptime(start.split(".")[0],"%Y-%m-%d %H:%M:%S")
    endTime = datetime.strptime(end.split(".")[0],"%Y-%m-%d %H:%M:%S")
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append((startTime + diff * i).strftime("%Y-%m-%d %H:%M:%S"))
    print(timeStamps)
    timeStamps=[start]+timeStamps[1:]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses

def float_range(start, end, intv):
    startTime = float(start)
    endTime = float(end)
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append((startTime + diff * i))
    timeStamps=[start]+timeStamps[1:]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses

def int_range(start, end, intv):
    startTime = int(start)
    endTime = int(end)
    diff = (endTime  - startTime ) / intv
    timeStamps=[]
    for i in range(intv):
        timeStamps.append(int((startTime + diff * i)))
    timeStamps=[start]+timeStamps[1:]
    timeStamps.append(end)
    whereClauses=[]
    for i in range(len(timeStamps)-1):
        whereClauses.append((timeStamps[i],timeStamps[i+1]))
    return whereClauses

class PyStreamCallback(InputStreamCallback):
    def __init__(self,interval=5):
        self.interval=interval
        pass
    def process(self,inputStream):
        text = IOUtils.toString(inputStream, StandardCharsets.UTF_8)
        jsonObj = json.loads(text)
        max_id=jsonObj["MAX_ID"]
        min_id=jsonObj["MIN_ID"]
        if(max_id==min_id):
            self.whereClauses=[]
        else:
            self.whereClauses=date_range(min_id,max_id,self.interval)


flowFile = session.get()
if (flowFile != None):
    try:
        callback = PyStreamCallback(interval=intervals.asInteger())
    except:
        callback=PyStreamCallback()
    session.read(flowFile,callback)
    for clause in callback.whereClauses:
        flowFile1=session.create(flowFile)
        flowFile1 = session.putAttribute(flowFile1, "from",str(clause[0]))
        flowFile1=session.putAttribute(flowFile1,"to",str(clause[1]))
        session.transfer(flowFile1,REL_SUCCESS)
    session.remove(flowFile)

# %%
data="""{"Id":"a0Z0U000001rW7BUAU","SystemModstamp":"2018-08-30T16:54:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0005","CreatedDate":"2018-08-30T16:54:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-08-30T16:54:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"Account","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":null,"cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Object"}
{"Id":"a0Z0U000001rW7CUAU","SystemModstamp":"2018-08-30T16:54:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0006","CreatedDate":"2018-08-30T16:54:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-08-30T16:54:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"TES","cwbtool__ComponentName__c":"Account_Manager__c","cwbtool__DataSource__c":null,"cwbtool__Definition__c":"TEst","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rW7DUAU","SystemModstamp":"2018-08-30T16:54:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0007","CreatedDate":"2018-08-30T16:54:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-08-30T16:54:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"TE","cwbtool__ComponentName__c":"Account_Number__c","cwbtool__DataSource__c":null,"cwbtool__Definition__c":"TESt","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rW7EUAU","SystemModstamp":"2018-08-30T16:54:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0008","CreatedDate":"2018-08-30T16:54:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-08-30T16:54:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"TEST","cwbtool__ComponentName__c":"Account_Number_External_ID__c","cwbtool__DataSource__c":null,"cwbtool__Definition__c":"Test","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkSUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0009","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"AccountNumber","cwbtool__DataSource__c":"MDM, SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnaUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0203","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the Servicing interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnZUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0202","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Servicer_UPB_M__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the value of the Servicer UPB.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnYUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0201","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Servicer_Rank_Number__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates where the Servicer ranks within the peer group.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnXUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0200","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Servicer_Rank_Loan_Count__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates how the Servicer ranks overall by loan count compared to other Servicers.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnWUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0199","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Servicer_Rank_Group__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the rank of the peer group.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnVUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0198","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicer_Profile__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates additional Servicing related profile details and comments regarding an Account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnUUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0197","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Servicer_Loan_Count__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the count of the Servicer's loans.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnTUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0196","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Servicer_Group_Count__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the number of Servicers within a peer group.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnSUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0195","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Servicer_Family_Number__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"This field contains the customer number that, according to the Servicer business area, is the parent of an affiliated group of Seller / Servicers. Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnRUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0194","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Servicer_Family_Name__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"This field contains the customer name that, according to the Servicer business area, is the parent of an affiliated group of Seller / Servicers. Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnQUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0193","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Service_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This is the Service Type field that will be used to identify the type(s) of service a Secondary Market Adviser (SMA) provides.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnPUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0192","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Seller_Family_Number__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"This field contains the customer number that, according to the Seller business area, is the parent of an affiliated group of Ã¦Seller / Servicers. Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnOUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0191","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Seller_Family_Name__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"This field contains the customer name that, according to the Seller business area, is the parent of an affiliated group of Ã¦Seller / Servicers. Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnNUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0190","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Sell_Servicing_Released__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents whether a particular seller/servicer has Sell Servicing Released. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnMUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0189","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"SDQ_Rate_Prior_Mth__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"SDQ rate for the prior month. Sourced from SPP.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnLUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0188","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"SDQ_Rate__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the serious delinquency rate count.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnKUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0187","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"SDQ_Count__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the serious delinquency loan count.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnJUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0186","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"S_S_Type__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"This field contains the classification code for the customer used to indicate if the customer is a seller, servicer, seller/servicer etc. Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnIUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0185","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"S_S_Name__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Name of the Seller-Servicer","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnHUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0184","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"S_P_Rating__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"ACIS Re-Insurance","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnGUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0183","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_UCDP_DI__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the UCDP DI interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnFUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0182","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the Servicing interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnEUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0181","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_Pricing_Execution__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the Pricing Execution interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnDUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0180","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_LQA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LQA S2S interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmpUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0156","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Pricing_Eligibility_PPE_SMA__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate what SMA the seller-servicer purchases PPE services from, if any.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmoUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0155","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Pricing_Eligibility_PPE_Comments__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to leave comments about the PPE SMA usage at the seller-servicer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmnUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0154","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"PPE__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate whether or not the seller-servicer purchases PPE services from an SMA.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmmUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0153","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"PhotoUrl","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmlUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0152","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"Phone","cwbtool__DataSource__c":"MDM, SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmkUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0151","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"PE_S2S__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmjUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0150","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"ParentId","cwbtool__DataSource__c":"MDM, SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmiUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0149","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Ownership_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"The Ownership Type field is for categorizing privately owned companies.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmhUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0148","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Ownership_Comments__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is for writing in details about the ownership of an SMA.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmgUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0147","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"Ownership","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmfUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0146","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"OwnerName__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Created in order to get over the max 10 object references limit","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmeUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0145","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"OwnerId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmdUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0144","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Other_Market_Share__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is for indicating the SMA's market share that is neither Freddie nor Fannie.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmcUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0143","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Other_Account_Number__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is manually populated and it is the Other Account Number for MSPs and HFAs.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmbUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0142","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Organization_Identifier__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"Unique identifier for a counterparty or related organization .Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmaUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0141","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External ID","cwbtool__ComponentName__c":"OIM_Legacy_ID__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmZUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0140","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"NumberOfEmployees","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmYUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0139","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Number_of_Freddie_Customers__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field identifies the number of Freddie Customers an SMA supports.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmXUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0138","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Number_of_Fannie_Customers__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field identifies the number of Competitor Customers.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmWUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0137","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Number_of_Employees__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"The Number of Employees field serves for detailing the size of the SMA organization.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmVUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0136","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Number_of_Customers_Brokers__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"The Number of Customers - Brokers field serves to detail how many of the SMA's customers (Seller-Servicers) are Brokers.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmUUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0135","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Number_of_Customers_Bankers__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"The Number of Customers - Bankers field details how many of the SMA's customers (Seller-Servicers) are bankers.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmTUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0134","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"Notification_Change_Date_Time__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Definition:  Date organization name or status changes in Counterparty Compliance Tracking System.   Source:  Counterparty Compliance Tracking System","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmSUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0133","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"Notification__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Definition:   Change type, name or status changes in Counterparty Compliance Tracking System.  Source:  Counterparty Compliance Tracking System","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm7UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0112","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Lender_Segment__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"This field represents a group of Freddie Mac customers which are related to each other in some way that is useful for sales, marketing or reporting purposes.  Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles except for the Integration & SA profiles","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm6UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0111","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"LCLA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the LCLA S2S interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm5UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0110","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"LCLA_Customer_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the number of customers which the Vendor supports for the LCLA interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm4UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0109","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"LCLA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the LCLA Browser interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm3UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0108","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"LastViewedDate","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm2UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0107","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"LastReferencedDate","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm1UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0106","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"LastModifiedDate","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm0UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0105","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"LastModifiedById","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflzUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0104","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"LastActivityDate","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflyUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0103","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"JigsawCompanyId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflxUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0102","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"Jigsaw","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflwUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0101","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"IsDeleted","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflvUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0100","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Investor_Tier__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"STACR Investor Tier","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfluUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0099","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Internal_Counterparty_Rating__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This is a picklist field where an ACIS reinsurer internal counterparty rating can be assigned to a CRT investor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfltUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0098","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"Institution_Type__c","cwbtool__DataSource__c":"SFDC, MDM","cwbtool__Definition__c":"This code categorizes institutions by the type of organization (e.g., Federal Savings Bank, Savings and Loan, etc.).","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnCUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0179","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_LQA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LQA Browser interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnBUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0178","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_LPA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LPA S2S interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnAUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0177","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_LPA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LPA Browser interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn9UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0176","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_Loan_Selling_Advisor__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the Loan Selling Advisor interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn8UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0175","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_LCLA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LCLA S2S interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn7UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0174","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Rollout_Date_LCLA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LCLA Browser interface was rolled out by the Vendor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn6UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0173","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Risk_Management_SMA__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate what SMA the Seller-Servicer purchases Hedging, etc. services from, if any.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn5UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0172","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Risk_Management_Level_of_Service__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate the level of service provided by the SMA to the seller-servicer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn4UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0171","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Risk_Management_Comments__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to leave comments about the Hedging, etc. usage at the seller-servicer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn3UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0170","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Risk_Management__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate if the seller-servicer purchases Hedging, etc. services from an SMA.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn2UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0169","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Requires_SSAR__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Checkbox to denote whether the account requires an SSAR","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn1UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0168","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Requires_Servicing_Strategic_Plan__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfn0UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0167","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Requires_Quarterly_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Maintained by Sales Support  to indicate which accounts will be covered in QA process; drives work flow and reporting","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmzUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0166","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Requires_BPR__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Allows the Servicing Team to indicate whether an Account requires the creation of a BPR.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmyUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0165","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Related_3rd_Party_Agreement__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmxUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0164","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External ID","cwbtool__ComponentName__c":"Regulatory_ID__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmwUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0163","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Region__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This is a picklist field used to specify the region of an individual CRT investor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmvUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0162","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"RecordTypeId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmuUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0161","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"Rating","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmtUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0160","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Product_Group__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This is a picklist field where one or more of the following credit risk transfer product groups can be selected to indicate which product groups an individual CRT investor is participating in: STACR, ACIS, WLS, or Other.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmsUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0159","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Product__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Vendor Management team. This field indicates the Interfaces a Vendor has.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmrUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0158","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Prime_Location_Flag__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field identifies if the institution location is the home office or a branch office.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmqUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0157","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Pricing_Execution__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the Pricing Execution interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmRUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0132","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"Name","cwbtool__DataSource__c":"MDM, OIM","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmQUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0131","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Multilender__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents whether a particular seller/servicer is eligible as a Multilender. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmPUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0130","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"MSR_Management_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate what MSR Management service type the seller-servicer purchases from the SMA.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmOUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0129","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"MSR_Management_SMA__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate what SMA the seller-servicer purchases MSR Management services from, if any.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmNUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0128","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"MSR_Management_Comments__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to leave comments about the MSR Management services usage at the seller-servicer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmMUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0127","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"MSR_Management__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate if the seller-servicer purchases MSR Management services from an SMA.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmLUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0126","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"MasterRecordId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmKUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0125","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Mandatory__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents the effective and expiration dates for a particular seller/servicer being eligible for Mandatory offerings. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmJUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0124","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Main_S_S__c","cwbtool__DataSource__c":"MDM, OIM","cwbtool__Definition__c":"Designates the main seller-servicer if the Account is a broker account of if the s/s number equal the seller family number","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmIUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0123","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"LSA_S2S__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmHUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0122","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"LQA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the LQA S2S interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmGUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0121","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"LQA_Customer_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the number of customers which the Vendor supports for the LQA interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmFUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0120","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"LQA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the LQA Browser interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmEUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0119","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"LPA_TPO_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the number of customers which the Vendor supports for the LPA TPO Count interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmDUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0118","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"LPA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the LPA S2S interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmCUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0117","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"LPA_Customer_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the number of customers which the Vendor supports for the LPA interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmBUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0116","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"LPA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the LPA Browser interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfmAUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0115","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"LOS_Vendor_Product_Version__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Loan origination systems used by the customer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm9UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0114","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Loan_Selling_Advisor_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the number of customers which the Vendor supports for the Loan Selling Advisor interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfm8UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0113","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Loan_Selling_Advisor__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the Loan Selling Advisor interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflsUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0097","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Initiatives_Programs__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Maintained by AE or Sales Support to indicate initiatives, programs, pilots in which the customer is engaged; drives communications and tracking","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflrUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0096","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"Industry","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflqUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0095","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Id","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflpUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0094","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ICM_Key_Fields_Tracker_Missing__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfloUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0093","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ICM_Key_Fields_Progress_Tracker__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflnUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0092","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ICM_Key_Fields_Completeness__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflmUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0091","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"HFA_Partner__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfllUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0090","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Guide_Plus_Package__c","cwbtool__DataSource__c":"SFDC/Other System?","cwbtool__Definition__c":"indicates which of 15 possible packages the customer is on (if applicable).","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflkUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0089","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Guarantor__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents whether a particular seller/servicer is eligible as a Guarantor. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfljUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0088","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"GSE_Size__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Percent of the Securitized GSE Market represented by the account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfliUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0087","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"GSE_Rank__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Ordinal rank of account based on GSE size.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflhUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0086","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Grid_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the type of Grid a Servicer belong to.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflgUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0085","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Global_Family_Number__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"This field contains the customer number that identifies the global, or legal family. Ã¦The global family includes legal entities that are related through ownership. Ã¦The global family number is used for corporate-wide reporting and analysis purposes. Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflfUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0084","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Full_Bifurcation_Expiration_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field will be used by the Servicing Released team to maintain the full bifurcation expiration date of an Account's servicing released program eligibility.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfleUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0083","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Full_Bifurcation_Effective_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field will be used by the Servicing Released team to maintain the full bifurcation effective date of an Account's servicing released program eligibility.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfldUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0082","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Full_Bifurcation_Approval_Amt__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field will be used by the Servicing Released team to maintain the full bifurcation approval dollar amount of an Account's servicing released program eligibility.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflcUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0081","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Full_Bif_Initial_Approval_Expiration__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field will be used by the Servicing Released team to maintain the full bifurcation initial approval expiration date of an Account's servicing released program","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflbUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0080","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Freddie_Market_Share__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is for indicating the SMA's market share of Freddie customers.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflaUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0079","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Footprint__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Maintained by AE to indicate the accounts lending footprint (e.g. Ã±originates in all 50 states with highest concentration in the SoutheastÃ®)","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflZUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0078","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"FMR_Rating__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Internally computed Freddie Mac Risk Rating","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflYUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0077","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"FM_Portfolio_Percentage__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates Freddie Mac's portfolio percentage with a specific Servicer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflXUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0076","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"Fax","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl7UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0050","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"CPA_Recertification_Due_Date_copy__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This formula field will maintain the exact value of the 'CPA Recertification Due Date' field, but exists so that we can bucket this date field in a report AND show the value in its column.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl6UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0049","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CPA_Recertification_Due_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Definition:   Date organization must renew certification process.   Source:  Counter Party Authorization team","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl5UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0048","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"CPA_Recertification_Days_Overdue__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Number of days past the CPA Recertification due date.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl4UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0047","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CPA_Compliant_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Definition:   Date organization has completed certification process.   Source:  Counter Party Authorization team","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl3UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0046","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CPA_Case_Created__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This is a checkbox field which will be manually updated to TRUE by a COTS Provisioning user to indicate that a counterparty authorization Case (CPA Case) request has been created against the Account. The field will FALSE for new Accounts, and will be automatically updated to FALSE when an existing Account's Name or Status is changed.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl2UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0045","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Contract_Structure__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Indicates the contractual construct the customer is under.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl1UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0044","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Contact_Frequency_Num__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl0UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0043","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Contact_Frequency__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Maintained by AE to indicate the minimum number on-site visits a year; drives customer visit tracking report","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkzUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0042","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Channels__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Maintained by AE to define how customer originates (Retail, Wholesale, Correspondent, Internet)","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkyUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0041","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Category__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Manually loaded by CRM Admin to designate subgroupings within the Corporate segment to drive treatments/messaging","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkxUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0040","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"CAC_S2S__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkwUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0039","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Buy_Servicing_Released__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents whether a particular seller/servicer is has Buy Servicing Released. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkvUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0038","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Business_Relationship_Narrative__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Maintained by AE to help colleagues understand the account; used to populate Customer Meeting Summary Strategic Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkuUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0037","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Business_Relationship_Check__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfktUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0036","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Bottom_25_PCT_NPL__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the percentage of Nonperforming loans within the bottom 25%.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfksUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0035","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Bottom_25_Last_3_Months__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Indicates if Seller-Servicers default management is in the Bottom 25 percentile for the last 3 months.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkrUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0034","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Bottom_25_DM_Rank__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Indicates if Seller-Servicers default management is in the Bottom 25 percentile for the most recent month.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkqUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0033","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"BillingStreet","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkpUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0032","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"BillingState","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflWUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0075","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Fannie_Market_Share__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is for indicating the SMA's market share of Fannie customers.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflVUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0074","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Expiration_Date__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflUUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0073","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Document_Custodian__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents whether a particular seller/servicer acts as a Document Custodian for itself. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflTUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0072","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Description_Check__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflSUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0071","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Description","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflRUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0070","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Delayed_Note__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents whether a particular seller/servicer is eligible for Delayed Note(s). Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflQUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0069","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Default_Management_Performance__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Checked if the Account's NPL is in bottom 25%","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflPUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0068","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Data_Quality_Score__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflOUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0067","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Data_Quality_Description__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflNUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0066","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Custodian_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflMUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0065","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CSR_Status__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field will be used by the Servicing Released team to maintain the Status of an Account's cash servicing-released program eligibility.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflLUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0064","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CSR_Expiration_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field will be used by the Servicing Released team to maintain an Account's expiration date of its cash servicing-released program eligibility.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflKUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0063","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CSR_Effective_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field will be used by the Servicing Released team to manually maintain an Account's effective date of its cash servicing-released program eligibility.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflJUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0062","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"CRT_Key_Fields_Tracker_Missing__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflIUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0061","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"CRT_Key_Fields_Progress_Tracker__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflHUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0060","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"CRT_Key_Fields_Completeness__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflGUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0059","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"CRMOD_Id__c","cwbtool__DataSource__c":"CRMOD","cwbtool__Definition__c":"This field stores legacy crm on demand id","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflFUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0058","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Credit_Rating__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the credit rating of the Account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflEUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0057","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"CreatedDate","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflDUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0056","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"CreatedById","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflCUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0055","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"CPM_Status__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"This field will store the status of an Account based on account status in MDM (Active, Delete, etc)","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflBUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0054","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External ID","cwbtool__ComponentName__c":"CPM_Parent_Master_ID__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"Parent Master ID sourced from the Counterparty Master system.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rflAUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0053","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External ID","cwbtool__ComponentName__c":"CPM_Master_ID__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"Master ID sourced from the Counterparty Master system.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl9UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0052","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"CPM_Account_Name__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfl8UAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0051","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CPA_Stage__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Definition:   Organization's current position in the Counter Party Authorization recertification process.   Source:  Counter Party Authorization team","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkoUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0031","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"BillingPostalCode","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfknUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0030","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"BillingLongitude","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkmUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0029","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"BillingLatitude","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfklUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0028","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"BillingGeocodeAccuracy","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkkUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0027","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"BillingCountry","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkjUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0026","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"BillingCity","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkiUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0025","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"BillingAddress","cwbtool__DataSource__c":"SFDC, MDM","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkhUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0024","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Best_Efforts__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents the effective and expiration dates for a particular seller/servicer being eligible for Best Efforts offerings.  Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkgUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0023","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"ARM_s__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents the whether a particular seller/servicer is eligible for ARMs offering. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkfUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0022","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"AnnualRevenue","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkeUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0021","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Annual_Servicing_Strategy__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Annual customer strategy and metric goals for Servicing","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkdUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0020","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Annual_Servicing_Goal__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Customer specific objective/metrics for Servicing","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkcUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0019","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"AM_Best_Rating__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This is a picklist field where an ACIS reinsurer A.M. Best rating can be assigned to a CRT investor.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkbUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0018","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Alternate_Regulatory_ID__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkaUAA","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0017","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Alternate_Name__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"Field will come from MDM for Seller/Servicer Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkZUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0016","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Alliance_Participation__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Designation of industry trade group program in which customer participates.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkYUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0015","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Alliance_Member__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Designation of industry trade group program in which the customer is a member.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkXUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0014","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"All_in_Pricing__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkWUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0013","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Aggregator_for_Bifurcated_Offerings__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents whether a particular seller/servicer is eligible to be an aggregator for bifurcated offerings. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkVUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0012","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Advisory_Boards_From_Contacts_for_calc__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkUUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0011","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Advisory_Boards_From_Contacts__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Advisory Boards for which Contacts associated to this Account are a part of. This field is populated based on the advisory boards selected at the Contact level.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfkTUAQ","SystemModstamp":"2018-09-12T20:45:27.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0010","CreatedDate":"2018-09-12T20:45:27.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:27.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"AccountSource","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rW79UAE","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0004","CreatedDate":"2018-08-30T16:09:04.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External ID","cwbtool__ComponentName__c":"Account_Number_External_ID__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used for initial data migration purposes only.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001PWbmUAG","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0000","CreatedDate":"2018-08-16T13:49:43.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Account_Executive_Email_for_Eloqua__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfolUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0276","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"WHL_Key_Fields_Tracker_Missing__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfokUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0275","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"WHL_Key_Fields_Progress_Tracker__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfojUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0274","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"WHL_Key_Fields_Completeness__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoiUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0273","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"Website","cwbtool__DataSource__c":"SFDC, MDM","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfohUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0272","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_UCDP_DI__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the UCDP DI interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfogUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0271","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the Servicing interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfofUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0270","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_Pricing_Execution__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the Pricing Execution interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoeUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0269","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_LQA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LQA S2S interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfodUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0268","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_LQA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LQA Browser interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoRUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0256","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Ultimate_Parent_Name__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"Ultimate Parent Account name displayed in plain text","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoQUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0255","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Ultimate_Parent_ID__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoPUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0254","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Ultimate_Parent__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"Display the name of the ultimate parent account in the hierarchy.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoOUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0253","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"UCDP_Lender__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoNUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0252","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"UCDP_DI__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if the Vendor supports the UCDP DI interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoMUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0251","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Type","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoLUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0250","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"TPO_Key_Fields_Tracker_Missing__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoKUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0249","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"TPO_Key_Fields_Progress_Tracker__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoJUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0248","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"TPO_Key_Fields_Completeness__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoIUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0247","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Total_Participant_Amount__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Roll-Up Summary from the participant object so show the total number of participants associated to the Account","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoHUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0246","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Total_Number_of_Customers__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the total number of SMA customers, including both bankers and brokers.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoGUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0245","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"TickerSymbol","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoFUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0244","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"Third_Party_Document_Custodian__c","cwbtool__DataSource__c":"OIM","cwbtool__Definition__c":"This field represents whether a particular seller/servicer acts as a 3rd Party Document Custodian. Field will come from OIM for TPO Accounts and should be Read-Only to all profiles for this Account Record Type except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoEUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0243","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_UCDP_DI__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the UCDP DI interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoDUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0242","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the Servicing interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoCUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0241","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_Pricing_Execution__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the Pricing Execution interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoBUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0240","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_LQA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the LQA S2S interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoAUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0239","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_LQA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the LQA Browser interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo9UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0238","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_LPA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the LPA S2S interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo8UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0237","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_LPA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the LPA Browser interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo7UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0236","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_Loan_Selling_Advisor__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the Loan Selling Advisor interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo6UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0235","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_LCLA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the LCLA S2S interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo5UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0234","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Testing_Begin_Date_LCLA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates the testing date for the LCLA Browser interface.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnkUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0213","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ShippingCity","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnjUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0212","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"ShippingAddress","cwbtool__DataSource__c":"MDM, OIM, SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfniUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0211","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"SF_Account_ID__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnhUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0210","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Servicing_Risk_Criteria__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Indicates the servicing risk level based upon predetermined criteria","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfngUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0209","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicing_Entity_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the Servicing Account entity type as a Regulated Entity or Mortgage Bank.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnfUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0208","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicing_Coverage_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Type of Servicing Coverage provided to the Account","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfneUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0207","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicing_Capacity_Performing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the number of Performing loans.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfndUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0206","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicing_Capacity_Nonperforming__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the number of Nonperforming loans.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfncUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0205","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicing_Bus_and_Relationship_Narrative__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Maintained by SAM/SAD or SAL to help colleagues understand the account; used to populate Servicing Strategic Account Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnbUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0204","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicing_Account_Plan_Review__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates if the Account is being reviewed for a Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfocUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0267","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_LPA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LPA S2S interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfobUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0266","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_LPA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LPA Browser interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoaUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0265","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_Loan_Selling_Advisor__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the Loan Selling Advisor interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoZUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0264","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_LCLA_S2S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LCLA S2S interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoYUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0263","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Verification_Date_LCLA_Browser__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field which indicates when the LCLA Browser interface was verified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoXUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0262","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Vendor_Key_Fields_Tracker_Missing__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoWUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0261","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Vendor_Key_Fields_Progress_Tracker__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoVUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0260","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Vendor_Key_Fields_Completeness__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoUUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0259","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Vendor_Account_Number__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is manually populated and it is the Vendor Account Number for origination Vendors who have built interfaces for Freddie products.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoTUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0258","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"VAB_Member__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Vendor Advisory Board","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfoSUAQ","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0257","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External Source","cwbtool__ComponentName__c":"USPS_Status__c","cwbtool__DataSource__c":"MDM","cwbtool__Definition__c":"USPS Status field will store the message provided by USPS Address Doctor to MDM, regarding any address.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo4UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0233","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Tax_Number__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Created for request # 560.This field should be visible on warehouse lender account page layout.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo3UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0232","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"SystemModstamp","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"0","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo2UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0231","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"SubAccountType__c","cwbtool__DataSource__c":"MDM, OIM, SFDC","cwbtool__Definition__c":"Field will come from MDM for Seller/Servicer Accounts & will come from OIM for TPO Accounts and should be Read-Only to all profiles for these Account Record Types except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo1UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0230","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sub_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Maintained by CRT; Further identifies the type of Account; Not used on Seller Servicer or TPO Account Record types","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfo0UAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0229","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Updated via Multiple Sources","cwbtool__ComponentName__c":"SS_Status__c","cwbtool__DataSource__c":"MDM, OIM, SFDC","cwbtool__Definition__c":"Field will come from MDM for Seller/Servicer Accounts & will come from OIM for TPO Accounts and should be Read-Only to all profiles for these Account Record Types except for the Integration & SA profiles.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnzUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0228","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"SS_Key_Fields_Tracker_Missing__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnyUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0227","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"SS_Key_Fields_Progress_Tracker__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnxUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0226","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"SS_Key_Fields_Completeness__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnwUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0225","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"SMA_Name__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This formula field concatenates the names of the SMA Accounts selected in the following lookup fields on a Seller-Servicer: MSR Management SMA, Pricing Eligibility (PPE) SMA, and Risk Management SMA. Users can use this field to filter Seller-Servicer's by a specific SMA.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnvUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0224","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"SMA_Form_Compliance__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used to indicate what SMA legal form the Seller-Servicer uses.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnuUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0223","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"Site","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfntUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0222","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"SicDesc","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnsUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0221","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"Sic","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnrUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0220","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ShippingStreet","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnqUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0219","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ShippingState","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnpUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0218","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ShippingPostalCode","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnoUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0217","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ShippingLongitude","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnnUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0216","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ShippingLatitude","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnmUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0215","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ShippingGeocodeAccuracy","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rfnlUAA","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0214","CreatedDate":"2018-09-12T20:45:28.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"ShippingCountry","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rW78UAE","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0003","CreatedDate":"2018-08-30T16:09:04.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Account_Number__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Auto-Generated Account Number for created Accounts in Salesforce","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rW77UAE","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0002","CreatedDate":"2018-08-30T16:09:04.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Account_Manager__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Lookup to a user in Salesforce who is the designated Freddie manager of the specified Account","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rW76UAE","SystemModstamp":"2018-09-12T20:45:28.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0001","CreatedDate":"2018-08-30T16:09:04.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-12T20:45:28.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"Account","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":null,"cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Object"}
{"Id":"a0Z0U000001rgm8UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0297","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Credit_Quality_Control_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Credit/Quality Control Assessment as green, yellow, red, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm7UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0296","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"CreatedDate","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm6UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0295","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"CreatedById","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm5UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0294","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Counterparty_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Counterparty Trend as up, down, maintain or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm4UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0293","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Counterparty_Eligibility__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Counterparty Eligibility for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm3UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0292","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Counterparty_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Counterparty Assessment as green, yellow, red, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm2UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0291","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CORE_Operational_Review_Results__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding CORE Operational Review Results for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm1UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0290","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CORE__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding CORE for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm0UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0289","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Compliance_with_RTOB__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Compliance with RTOB for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglzUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0288","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Compensatory_Fees_Outstanding__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Compensatory Fees Outstanding for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglyUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0287","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Client_Objectives__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"As articulated by the account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglxUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0286","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Challenges__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Current challenges being faced with the client for the fiscal year","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglwUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0285","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Business_and_Relationship_Narrative__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding the Business and Relationship Narrative","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglvUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0284","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"BPR_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the date of the BPR.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgluUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0283","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Bottom_25_NPL__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays Bottom 25 % NPL from the Account. Field requested by the Servicing team. This field indicates the percentage of Nonperforming loans within the bottom 25%.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgltUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0282","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Manually Loaded via External Source","cwbtool__ComponentName__c":"Bottom_25_Indicator__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates if the Servicer is within the Bottom 25%.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglsUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0281","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Bankruptcy__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Bankruptcy for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglrUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0280","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Alternatives_to_Foreclosure__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Alternatives to Foreclosure for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglqUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0279","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"AE__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display the name of the Account Owner on the related Account record.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rglpUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0278","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Account__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Associate Account for which the Account Plan has been created","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgloUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0277","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"Account_Plan__c","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":null,"cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Object"}
{"Id":"a0Z0U000001rgmqUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0341","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Non-Reportable Data Type","cwbtool__ComponentName__c":"GoalsInitiativesIssues_Assmt_Trend_5_Img__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmpUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0340","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Non-Reportable Data Type","cwbtool__ComponentName__c":"GoalsInitiativesIssues_Assmt_Trend_4_Img__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmoUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0339","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Non-Reportable Data Type","cwbtool__ComponentName__c":"GoalsInitiativesIssues_Assmt_Trend_3_Img__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmnUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0338","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Non-Reportable Data Type","cwbtool__ComponentName__c":"GoalsInitiativesIssues_Assmt_Trend_2_Img__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmmUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0337","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Non-Reportable Data Type","cwbtool__ComponentName__c":"GoalsInitiativesIssues_Assmt_Trend_1_Img__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmlUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0336","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_Assmt_Trend_5__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmkUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0335","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_Assmt_Trend_4__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmjUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0334","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_Assmt_Trend_3__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmiUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0333","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_Assmt_Trend_2__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmhUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0332","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_Assmt_Trend_1__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmgUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0331","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_5__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmfUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0330","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_4__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmeUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0329","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_3__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmdUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0328","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_2__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmcUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0327","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goals_Initiatives_Issues_1__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmbUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0326","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goal_Outlier_Mgmt_Measure_Target__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Standard Outlier Mgmt Measure Target / Goal for all current FY Strategic Plans","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmaUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0325","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goal_Market_Share_Measure_Target__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Standard Market Share Measure Target / Goal for all current FY Strategic Plans","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmZUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0324","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goal_LAS_Measure_Target__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Standard LAS Measure Target / Goal for all current FY Strategic Plans","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmYUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0323","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goal_Customer_Engagement_Measure_Target__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Standard Customer Engagement Measure Target / Goal for all current FY Strategic Plans","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmXUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0322","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Goal_Affordable_Measure_Target__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Standard Affordable Measure Target / Goal for all current FY Strategic Plans","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmWUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0321","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"General_Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding General Servicing for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmVUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0320","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"FM_Portfolio_Percentage__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays FM Portfolio Percentage from the Account. Field requested by the Servicing team. This field indicates Freddie Mac's portfolio percentage with a specific Servicer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoPUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0438","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Year__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Year the Account plan is for.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoOUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0437","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Weaknesses__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Freddie Weaknesses in relation to the Customer","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoNUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0436","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"VP_of_Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Used in the Servicing Strategic Account Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoMUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0435","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"VP_of_Sales__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"User with the Account Team Role of Vice President of Sales for the associated Account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoLUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0434","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"VP_Approval_Datetime__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoKUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0433","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Non-Reportable Data Type","cwbtool__ComponentName__c":"View_SAP_Attachments__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Custom link to direct users to the attachments page.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoJUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0432","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Value_Proposition__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"How Freddie Mac contributes to client success.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoIUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0431","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Threats__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Freddie threats in relation to the Customer","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoHUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0430","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Terms_of_Business__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Terms of Business for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoGUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0429","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"SystemModstamp","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoFUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0428","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Supplemental_Metrics__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Supplemental Metrics for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoEUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0427","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Subservicing_Analysis__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Subservicing Analysis for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoDUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0426","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Subservicer_s__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Text area for Servicing to comment on subservicer information on their Servicing Strategic Account Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoCUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0425","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Subserviced_Client_s__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Text area for Servicing to comment on subserviced client information on their Servicing Strategic Account Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoBUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0424","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Sub_Servicer__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display whether or not the related Account acts as a Sub-Servicer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoAUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0423","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Strengths__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Freddie strengths in relation to the Customer","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo9UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0422","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Strategic_Positioning__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Summarizes overall approach with the Account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo8UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0421","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Strategic_Initiatives__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Description of strategic initiatives being undertaken with/by the client","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo7UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0420","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Status__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Completion status of the Account Plan as selected by a user.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo6UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0419","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"SS__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Seller-Servicer number for the related Account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo5UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0418","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Sourcing_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Sourcing Trend as up, down, maintain, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo4UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0417","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Sourcing_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Sourcing Assessment as green, yellow, red, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo3UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0416","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicing_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Servicing Trend as up, down, maintain, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo2UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0415","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicing_Capacity_Performing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the number of Performing loans.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo1UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0414","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicing_Capacity_Non_Performing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates the number of Nonperforming loans.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgo0UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0413","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicing_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Servicing Assessment as green, yellow, red, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnzUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0412","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicing_Agent__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by the Servicing team. This field indicates if the associated Account to the SAP is being sub-serviced.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnyUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0411","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Servicer_UPB_M__c","cwbtool__DataSource__c":"SPP","cwbtool__Definition__c":"Displays Servicer UPB ($M) from the Account. Field requested by the Servicing team. This field indicates the value of the Servicer UPB.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnxUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0410","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicer_Success_File_Review_QA__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Servicer Success File Review (QA) for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnwUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0409","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Servicer_Rank_Number__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays Servicer Rank Number from the Account. Field requested by the Servicing team. This field indicates where the Servicer ranks within the peer group.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnvUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0408","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Servicer_Rank_Loan_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays Servicer Rank Loan Count from the Account. Field requested by the Servicing team. This field indicates how the Servicer ranks overall by loan count compared to other Servicers.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnuUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0407","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Servicer_Rank_Group__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays Servicer Rank Group from the Account. Field requested by the Servicing team. This field indicates the rank of the peer group.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgntUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0406","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicer_Performance_Analysis__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnsUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0405","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Servicer_Loan_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays Servicer Loan Count from the Account. Field requested by the Servicing team. This field indicates the count of the Servicer's loans.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnrUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0404","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"Servicer_Group_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays Servicer Group Count from the Account. Field requested by the Servicing team. This field indicates the number of Servicers within a peer group.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnqUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0403","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Seriously_Delinquent_Loan_Portfolio__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Serious Delinquent Loan Portfolio for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnpUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0402","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Securitization_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Securitization Trend as up, down, maintain, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnoUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0401","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Securitization_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Securitization Assessment as green, yellow, red, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnnUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0400","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"SDQ_Rate__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays SDQ Rate from the Account. Field requested by the Servicing team. This field indicates the serious delinquency rate count.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnmUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0399","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Displays Externally Sourced or Duplicate Data","cwbtool__ComponentName__c":"SDQ_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays SDQ Count from the Account. Field requested by the Servicing team. This field indicates the serious delinquency loan count.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnlUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0398","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Scorecard_Performance__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Scorecard Performance for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnkUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0397","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"SAM__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Servicing Account Manager or Servicing Account Director.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnjUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0396","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sales_VP__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Sales VP from the Account","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgniUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0395","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"SAL__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Servicing Account Liaison.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnhUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0394","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"SAD__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Servicer Account Director for the associated account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgngUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0393","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Review_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the month and year for the review date of the account plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnfUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0392","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Requires_BPR__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays Requires BPR from the Account. This field indicates if an Account should be included within a BPR.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgneUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0391","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Reporting__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Reporting for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgndUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0390","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Remedy_and_Obligations_Mgmt__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Remedy and Obligations Management for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgncUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0389","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Relationship_Summary__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Relationship Summary for the Servicing Account Plan and BPR.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnbUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0388","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Relationship_Management__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Relationship Management for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnaUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0387","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"RecordTypeId","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnZUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0386","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Quality_Assurance__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Quality Assurance for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnYUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0385","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Pricing_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Pricing Trend as up, down, maintain, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnXUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0384","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Pricing_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Pricing Assessment as green, yellow, red, or N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnWUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0383","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Portfolio_Strategy_Transfers__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Portfolio Strategy/Transfers for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnVUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0382","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Plan_of_Action__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding the Plan of Action.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnUUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0381","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Performing_Loans__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Performing Loans for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnTUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0380","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Peer_Group__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the rank of the peer group.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnSUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0379","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"OwnerId","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnRUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0378","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Overall_Strategy_servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding the Overall Strategy.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnQUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0377","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Overall_Strategy__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Overall strategy for the Account","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnPUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0376","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Overall_Relationship_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Overall Relationship Trend as up, down, maintain, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnOUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0375","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Non-Reportable Data Type","cwbtool__ComponentName__c":"Overall_Relationship_Assessment_Trend_Im__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnNUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0374","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Overall_Relationship_Assessment_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnMUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0373","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Overall_Relationship_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Overall Relationship Assessment as green, yellow, red, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnLUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0372","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Other__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input additional analysis for an Account for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnKUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0371","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Opportunities__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Opportunities for Freddie in relation to the Customer","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnJUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0370","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Operations_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Operations Trend as up, down, maintain or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnIUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0369","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Operations_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Operations Assessment as green, yellow, red, or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnHUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0368","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"NPL_Retention_W_O__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding NPL-Retention Workout for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnGUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0367","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"NPL_Liquidation_W_O__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding NPL-Liquidation Workout for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnFUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0366","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"NPL_Foreclosure__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding NPL-Foreclosure for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnEUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0365","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"NPL_Collections_Cust_Serv__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding NPL-Collections/Customer Service for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnDUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0364","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"NPL__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding NPL for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnCUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0363","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"Name","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnBUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0362","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"MSR_Sales_or_TOS__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding MSR Sales or TOS for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgnAUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0361","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Mortgage_Insurance__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Mortgage Insurance for the Servicing Account Plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn9UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0360","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Month__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the month for which the account plan is created.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn8UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0359","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Loan_Count__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the number of loans.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn7UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0358","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"LastViewedDate","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn6UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0357","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"LastReferencedDate","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn5UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0356","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"LastModifiedDate","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn4UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0355","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"LastModifiedById","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn3UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0354","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"LastActivityDate","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn2UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0353","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Key_Drivers_Performance_Update_Status_5__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn1UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0352","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Key_Drivers_Performance_Update_Status_4__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgn0UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0351","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Key_Drivers_Performance_Update_Status_3__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmzUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0350","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Key_Drivers_Performance_Update_Status_2__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmyUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0349","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Key_Drivers_Performance_Update_Status_1__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmxUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0348","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"IsDeleted","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmwUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0347","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Investor_Reporting_Synthetic_Comparison__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Investor Reporting Synthetic Comparison for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmvUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0346","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Investor_Reporting__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Investor Reporting for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmuUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0345","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Internal_Comments__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input internal comments for an Account for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmtUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0344","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Internal__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if an account plan record should only be viewed and leveraged for internal FRE business purposes.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmsUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0343","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"Id","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmrUAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0342","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"High_Level_Action_Item__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding High Level Actions Items for the BPR.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmUUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0319","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Evaluation_Results__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding the Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmTUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0318","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Due_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Expected due date for a finalized Account Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmSUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0317","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"DOS__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display DOS from the Account","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmRUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0316","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Director_of_Sales__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"User with the Account Team Role of Director of Sales for the associated Account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmQUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0315","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Default_Management_Synthetic_Comparison__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Default Management Synthetic Comparison for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmPUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0314","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Default_Management_Peer_Comparison__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Default Management Peer Comparison for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmOUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0313","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Default_Management__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input analysis for an Account regarding Default Management for the Servicing Evaluation Summary.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmNUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0312","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Date_of_Last_Update__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date of last material update selected by AE.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmMUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0311","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Data_Year__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the year for the data in the account plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmLUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0310","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Data_Month__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the month of the data.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmKUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0309","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Data_Cycle_Year__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the year for the data cycle of the account plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmJUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0308","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Data_Cycle_Month__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the month for the data cycle of the account plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmIUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0307","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Data_Cycle__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the month and year for the data cycle of the account plan.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmHUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0306","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Custom_Goal_3_Measure_Target__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Custom Account Goal Measure/Target for the Current FY Strategic Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmGUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0305","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Custom_Goal_3__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Custom Account Goal for the Current FY Strategic Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmFUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0304","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Custom_Goal_2_Measure_Target__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Custom Account Goal Measure/Target for the Current FY Strategic Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmEUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0303","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Custom_Goal_2__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Custom Account Goal for the Current FY Strategic Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmDUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0302","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Custom_Goal_1_Measure_Target__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Custom Account Goal Measure/Target for the Current FY Strategic Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmCUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0301","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Custom_Goal_1__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Custom Account Goal for the Current FY Strategic Plan","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmBUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0300","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"CRMOD_Id__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgmAUAQ","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0299","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Credit_Rating__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Displays Credit Rating from the Account. Field requested by the Servicing team. This field indicates the credit rating of the Account.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgm9UAA","SystemModstamp":"2018-09-14T14:58:17.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0298","CreatedDate":"2018-09-14T14:58:17.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T14:58:17.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Credit_Quality_Control_Trend__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Credit/Quality Control Trend as up, down, maintain or N/A.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Account_Plan__c","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpsUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0514","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"FRE_Loan__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Borrower's FRE Loan # for which the case is associated. Loan information can be found in Loan Status Manager.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgptUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0515","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Id","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpuUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0516","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"ID_Form_Approved__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the ID form document was approved (or validated/perfected) during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpvUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0517","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"ID_Form_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the ID form document was initially received during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpwUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0518","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"IDs_PWs_Sent__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This checkbox field is used by the COTS Provisioning and TPO users to indicate whether or not the ID's and passswords have been sent during a COTS care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpxUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0519","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"In_Approval__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used by Credit Intake Approval. PLEASE DO NOT DELETE THIS FIELD.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpyUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0520","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"External ID","cwbtool__ComponentName__c":"inContact_ID__c","cwbtool__DataSource__c":"InContact","cwbtool__Definition__c":"Displays generate inContact call ID associated to the Case","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpzUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0521","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Initial_Source_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Designates the who was the initial source of the Case for ECU/BCU","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq0UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0522","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Internal__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates if a case should be only viewed and leveraged for internal FRE business purposes","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq1UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0523","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Internal_Comments__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Text field for users to provide internal comments on the case that should not be shared with the Customer.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq2UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0524","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Is_Logged_In_User__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Evaluates whether the logged in user is the same as the created by user on the Case record.  Utilized for a dynamic My Created Cases list view filter.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq3UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0525","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"IsClosed","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq4UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0526","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"IsClosedOnCreate","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq5UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0527","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"IsCreated__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Created for assignment rules.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq6UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0528","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"IsDeleted","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq7UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0529","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"IsEscalated","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq8UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0530","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"LastModifiedById","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgq9UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0531","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"LastModifiedDate","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqAUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0532","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"LastReferencedDate","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqBUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0533","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"LastViewedDate","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqCUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0534","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Legal_Letter_Approved__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the legal letter document was approved (or validated/perfected) during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqDUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0535","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Legal_Letter_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the legal letter document was initially received during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqEUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0536","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Manager_Approval__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This lookup field is used by the COTS Provisioning and TPO users to record the name of the manager who is responsible for approving a COTS counterparty authorization or care and maintenance request during the quality control check.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqFUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0537","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Manager_Approval_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to record the date on which the manager approved a COTS counterparty authorization or care and maintenance request during the quality control check.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqGUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0538","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"New_Interest_Rate__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Used for NACA cases to document new interest rate","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqHUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0539","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"of_Users__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"# of user affected by the submitted case","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqIUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0540","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Open_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Manually populated date field for when the case was opened. Used for cases not of type contact center or ecu/bcu.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqJUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0541","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Opportunity__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Lookup field to an associated Opportunity for which the case is about.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqKUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0542","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Origin","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqLUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0543","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Original_Interest_Rate__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Used for NACA cases to document original interest rate","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqNUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0545","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"OwnerId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqOUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0546","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"ParentId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqPUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0547","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Past_Due1__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display whether the case is past due based upon the Target Due Date specified.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqQUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0548","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Past_Due__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display whether or not a case exceeded the Target Due Date.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqRUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0549","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Pin_NACA_ID__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Unique pin provided to the borrower for an ECU/BCU case","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqSUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0550","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Priority","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqTUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0551","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Process_Reveiw_State__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used by Credit Intake Approval. PLEASE DO NOT DELETE THIS FIELD.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqUUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0552","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Product__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This picklist field is used by the COTS Provisioning and TPO users to record the specific product a particular transaction type is committed against during a COTS care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqVUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0553","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Purchase_Eligibility__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This checkbox field is used by the COTS Provisioning and TPO users to indicate the Purchase Eligibility (yes or no) during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqWUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0554","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Reason","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqXUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0555","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"RecordTypeId","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqYUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0556","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Refer_To_MCP__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Credit uses this field to determine if a request needs to be sent to Policy for review and corporate wide adoption","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqZUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0557","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Referring_Party__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Associated party of the person submitting a case on behalf of a borrower.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqaUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0558","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Referring_Party_Email__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Email of the person from the referring party.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqbUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0559","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Referring_Party_Name__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Name of the person from the referring party.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqcUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0560","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Referring_Party_Phone__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Phone of the person from the referring party.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqdUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0561","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Related_Software_Adoption_Opportunity__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Lookup to a parent (software adoption) opportunity a Case is associated to / about.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqeUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0562","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Remaining_Days__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display the days remaining until the Target Due Date.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqfUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0563","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Request_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field that indicates the date in which a Customer Credit case request was received from a customer by the Customer Credit Management team.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqgUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0564","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Request_Defined__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date field that indicates the date in which the process to resolve the Customer Credit case request has started.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqhUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0565","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Resolution_Result__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Categorization of the Case resolution for ECU/BCU","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqiUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0566","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Resolution_Summary__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Summary of the determined case resolution.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqjUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0567","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Reviewed_By_Credit__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqkUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0568","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Reviewed_By_Sales__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqlUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0569","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Risk__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by Customer Credit Management team. This field indicates the Risk as High, Medium or Low for Customer Credit cases. This field is dependent on the CCPE field.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqmUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0570","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Risk_Assessment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This checkbox field is used by the COTS Provisioning and TPO users to indicate if Risk Assessment has been completed (yes or no) during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqnUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0571","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"S_S__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display the Seller-Servicer Number for the Account related to the case.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqoUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0572","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sales_Decision__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqpUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0573","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sales_Denied_Reason__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqqUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0574","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sales_Description__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqrUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0575","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sales_Path__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqsUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0576","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sales_Recommendation__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqtUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0577","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sales_Subject__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgquUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0578","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Salesforce_Record_ID__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display the 18 character case safe Salesforce record id.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqvUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0579","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Secondary_Contact__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Lookup field to relate a Secondary Contact to a COTS Customer Integration or COTS TPO (UCDP request) case record.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqwUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0580","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Secondary_Contact_Email__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display the email address from the Contact record associated to the case as Secondary Contact.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqxUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0581","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Secondary_Contact_Phone__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Display the phone number from the Contact record associated to the case as Secondary Contact.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqyUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0582","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicer_Loan_Number__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field to input servicer loan number","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqzUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0583","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Servicer_Response__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr0UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0584","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Servicer_Response_Time__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr1UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0585","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Settlement_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"These fields are important for reporting needs","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr2UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0586","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"SourceId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr3UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0587","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Specified_Disaster__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr4UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0588","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Stage__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This picklist field is used by the COTS Provisioning and TPO users to indicate the current stage of a COTS counterparty authorization request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr5UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0589","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Stage_Start_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This picklist field will be automatically populated with today's date whenever the Stage field is modified. It can be used in reporting to determine how long a Case has been in its current stage.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr6UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0590","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Status","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr7UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0591","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sub_Category_New__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Most granular categorization of a Case. Dependent on Category.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr8UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0592","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Sub_Category_Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Most granular categorization of a Case. Dependent on Category.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgr9UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0593","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Sub_Category_Support__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrAUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0594","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Subject","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrBUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0595","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Submitted_To_Credit__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrCUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0596","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Submitted_To_Sales__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrDUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0597","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"SuppliedCompany","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrEUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0598","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"SuppliedEmail","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrFUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0599","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"SuppliedName","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrGUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0600","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"SuppliedPhone","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrHUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0601","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"SystemModstamp","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrIUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0602","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Target_Due_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Due date the Case is expected to be Closed.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrJUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0603","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Target_Timeframe__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Auto-populated based upon the difference between the Target Due Date and Request Defined Date.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrKUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0604","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Topic_New__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used by multiple business areas and it indicates the Topic that a case pertains to. For certain case records, this field drives the picklist values for the Category field.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrLUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0605","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Topic_Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used by multiple business areas and it indicates the Topic that a case pertains to. For certain case records, this field drives the picklist values for the Category field.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrMUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0606","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Topic_Support__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrNUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0607","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"TPTS_TriAgr_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to record the date on which the TPTS tri agreement document was initially received during a COTS care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrOUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0608","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Trans_Union_Ordered__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to indicate the Trans Union order date during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrPUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0609","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Trans_Union_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to indicate the Trans Union received date during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrQUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0610","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Transaction_Type__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This picklist field is used by the COTS Provisioning and TPO users to record the type of transaction committed in a particular product during a COTS care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrRUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0611","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Type","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrSUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0612","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Type_of_CCPE__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by Customer Credit Management team. This field indicates the Type of CCPE (Customer Credit Policy Exception) as Level 1, Level 2, Level 3 or De-Minimis for Customer Credit cases. This field is dependent on the CCPE field.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrTUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0613","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Unique_Identifier__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Used to place FHFA and OIG Case Numbers","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrUUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0614","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Volume__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by Customer Credit Management team. This field indicates the Volume as High, Medium or Low for Customer Credit cases. This field is dependent on the CCPE field.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrVUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0615","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"W_9_Approved__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrWUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0616","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"W_9_Received__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrXUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0617","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"X1st_QC_Analyst__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This lookup field is used by the COTS Provisioning and TPO users to record the name of the analyst who is responsible for the quality control check during a COTS counterparty authorization or care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrYUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0618","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"X1st_QC_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to record the date on which the analyst approved a COTS counterparty authorization or care and maintenance request during the quality control check.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgrZUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0619","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"ZZ_Credit__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Business Area for Customer Credit cases as either Credit Flow or Credit Bulk & Property Affordable","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgofUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0439","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":null,"cwbtool__ComponentName__c":"Case","cwbtool__DataSource__c":null,"cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":null,"cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Object"}
{"Id":"a0Z0U000001rgogUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0440","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"AccountId","cwbtool__DataSource__c":"SFDC, MDM, OIM","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgohUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0441","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Addl_Required_Approvers__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoiUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0442","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Approval_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"These field is important for reporting needs","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgojUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0443","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"AssetId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgokUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0444","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Assisted_By__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Business area who assisted in the resolution of the case","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgolUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0445","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Board_Resolution_Approved__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the board resolution document was approved (or validated/perfected) during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgomUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0446","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Board_Resolution_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the board resolution document was initially received during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgonUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0447","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Business_Area_Credit__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is a new Business Area field created as part of merging the Business area global pick list. Will be used every where in places where the Business Area (Credit__c ) field has been used. This field indicates the Business Area for Customer Credit cases as either Credit Flow or Credit Bulk & Property Affordable","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgooUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0448","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Standard Field - Not in Use","cwbtool__ComponentName__c":"BusinessHoursId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgopUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0449","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Call_Issue__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Describes issues associated with the connection of an in progress call with the customer (i.e. static, etc.)","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoqUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0450","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Case_Age_Calendar_Days__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Case Age Calendar Days for all record types EXCEPT contact center & ecu/bcu. Case Age in Calendar Days counted from the custom created date of the record to Today if status is not closed, otherwise custom close date minus custom open date.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgorUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0451","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Case_Age_Days__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Case Age in Calendar Days counted from the system created date of the record to Today if status is not closed, otherwise system close date minus system open date. To be utilized by Contact Center and ECU/BCU","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgosUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0452","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"CaseNumber","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgotUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0453","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Category_New__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used by multiple business areas and it indicates the Category that a case pertains to. For certain case records, this field is dependent on the Type field.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgouUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0454","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Category_Servicing__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used by multiple business areas and it indicates the Category that a case pertains to. For certain case records, this field is dependent on the Type field.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgovUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0455","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Category_Support__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgowUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0456","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CCPE__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by Customer Credit Management team. This field indicates the CCPE (Customer Credit Policy Exception) as yes or no for Customer Credit cases. If CCPE is yes, then this drives the picklist values for the Type of CCPE, Volume and Risk fields.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoxUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0457","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Cert_of_Incumbency_Approved__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the certificate of incumbency document was approved (or validated/perfected) during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgoyUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0458","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Cert_of_Incumbency_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the certificate of incumbency document was initially received during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgozUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0459","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Close_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Manually populated date field for when the case was closed. Used for cases not of type contact center or ecu/bcu.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp0UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0460","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Closed_Reason__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Additional level of detail indicating why the case was closed","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp1UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0461","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"ClosedDate","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp2UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0462","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Communication_Not_Required__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Additional Communication not required by the ECU/BCU","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp3UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0463","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"ContactEmail","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp4UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0464","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"ContactFax","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp5UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0465","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"ContactId","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp6UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0466","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"ContactMobile","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp7UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0467","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"ContactPhone","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp8UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0468","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"COPS_Order_del__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgp9UAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0469","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CPA_Compliant_Status__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This picklist field is used by the COTS Provisioning team to specify the compliance status of an Account as a result of its counterparty authorization request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpAUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0470","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"CPA_Doc_s_Not_Required__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This multi-select picklist field is used by the COTS Provisioning team to denote that 1 or more of the 6 counterparty authorization documents is not required and therefore will not have a received date or approved date.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpBUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0471","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"CreatedById","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpCUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0472","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"CreatedDate","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpDUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0473","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Credit_Denied_Reason__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpEUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0474","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Read Only","cwbtool__ComponentName__c":"Credit_Intake_Process_Through__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This Field is used by Credit Intake Approval Process. PLEASE DO NOT DELETE THIS FIELD.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpFUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0475","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Credit_WaiverTOB_to_Go__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by Customer Credit Management team. This field indicates the Credit Waiver/TOB to Go as Guide, CCPE, N/A for Customer Credit cases.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpGUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0476","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"CRMOD_Id__c","cwbtool__DataSource__c":"CRMOD","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpHUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0477","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Data_Compare__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This checkbox field is used by the COTS Provisioning and TPO users to indicate if Data Compare has been completed (yes or no) during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpIUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0478","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Data_Quality_Description__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpJUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0479","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Data_Quality_Score__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpLUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0481","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Deal_Complexity__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Field requested by Customer Credit Management team. This field indicates the Deal Complexity as basic, medium, complex or significant for Customer Credit cases.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpMUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0482","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Decision__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field indicates the Decision as approved, denied or canceled for a Customer Credit case which has been closed.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpNUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0483","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Description","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpOUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0484","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Document_Upload_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This lookup field is used by the COTS Provisioning and TPO users to record the date on which the user uploaded the document in the quality control check during a COTS care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpPUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0485","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Document_Uploaded_By__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This lookup field is used by the COTS Provisioning and TPO users to record the name of the user who uploaded the document in the quality control check during a COTS care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpQUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0486","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Email_Bounce_Back__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpRUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0487","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Email_Comments__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Used to capture email comments to be sent to and visible to the customer upon case closure","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpSUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0488","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Environment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This picklist field is used by the COTS Provisioning and TPO users to indicate which environment an LQA care and maintenance request is related to.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpTUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0489","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Equifax_Ordered__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to indicate the Equifax order date during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpUUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0490","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Equifax_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to indicate the Equifax received date during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpVUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0491","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Escalated__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This checkbox field is used by the COTS Provisioning and TPO users to indicate at the point of receipt if a COTS care and maintenance request has already been escalated.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpWUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0492","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Escalated_Decision__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Used by Credit to determine if a Credit Case is ultimately approved or denied if the credit decision is different from the Sales recommendation","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpXUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0493","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Escalated_To__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Determines the party / queue the case has been escalated to","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpYUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0494","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Escalation_Approved_Denied_Reason__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Reason the escalated credit case was denied.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpZUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0495","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Escalation_Assignment__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpbUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0497","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Escalation_Resolution__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":null,"cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpcUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0498","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Escalation_Reviewed__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Reviewed date if a Sales recommends and credit denies a waiver / TOB request","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpdUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0499","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Escalation_Status__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This field is used by Sales to indicate the Escalation Status if Sales = Recommends and Credit = Denies for a Customer Credit Case Wavier","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpeUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0500","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Eviction_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date of scheduled eviction","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpfUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0501","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Exceeds_Target_Timeframe_Reason__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Credit uses this field to note the reason the target due date was exceeded if the case was closed after the target due date.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpgUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0502","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Exhibit_98_Approved__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgphUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0503","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"ERROR:#N/A","cwbtool__ComponentName__c":"Exhibit_98_Received__c","cwbtool__DataSource__c":"ERROR:#N/A","cwbtool__Definition__c":"ERROR:#N/A","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpiUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0504","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Experian_Ordered__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to indicate the Experian order date during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpjUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0505","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Experian_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to indicate the Experian received date during an LQA-related care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpkUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0506","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"FCL_Sale_Date__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Date of scheduled foreclosure sale date","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgplUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0507","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"First_Submission_Accuracy__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Utilized by COTS Provisioning to indicate when a Customer has provided sufficient/accurate documentation on the first attempt.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpmUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0508","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Forbearance_Amount__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Used for NACA cases to document forbearance","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpnUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0509","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Form_483_Approved__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the form 483 document was approved (or validated/perfected) during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpoUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0510","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Form_483_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to record the date on which the form 483 document was initially received during a COTS counterparty authorization or care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgppUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0511","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Custom Field - Not in Use (Z)","cwbtool__ComponentName__c":"Form_960_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to record the date on which the form 960 document was initially received during a COTS care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpqUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0512","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Form_987E_Approved__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning team to record the date on which the form 987E document was approved (or validated/perfected) during the counterparty authorization request process.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgprUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0513","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Form_987E_Recvd__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"This date field is used by the COTS Provisioning and TPO users to record the date on which the form 987E document was initially received during a COTS counterparty authorization or care and maintenance request.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgqMUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0544","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Other_Description__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Required description if \\"Other\\" is selected as the \\"Sub-Category\\" value.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpKUAQ","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0480","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Date_Escalated__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Workflow populates this field as the current date when an \\"Escalated To\\" value is selected.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}
{"Id":"a0Z0U000001rgpaUAA","SystemModstamp":"2018-09-14T15:22:01.000Z","OwnerId":"00536000004vrMvAAI","IsDeleted":"FALSE","Name":"METAD-0496","CreatedDate":"2018-09-14T15:22:01.000Z","CreatedById":"00536000004vrMvAAI","LastModifiedDate":"2018-09-14T15:22:01.000Z","LastModifiedById":"00536000004vrMvAAI","cwbtool__BusinessRule__c":"Sourced in SFDC - Editable","cwbtool__ComponentName__c":"Escalation_Reason__c","cwbtool__DataSource__c":"SFDC","cwbtool__Definition__c":"Reason the case is being escalated. Must be provided upon populating the \\"Escalated To\\" field.","cwbtool__GDPRDataType__c":null,"cwbtool__InternalDatabaseMapping__c":null,"cwbtool__LinktoTrailhead__c":null,"cwbtool__Parent__c":"Case","cwbtool__Published__c":"TRUE","cwbtool__Requester__c":null,"cwbtool__Type__c":"Field"}"""

# %%
import json
schema={}
for line in data.split("\n"):
    jsonObj = json.loads(line)
    component = jsonObj["cwbtool__ComponentName__c"]
    compParent=jsonObj["cwbtool__Parent__c"]
    compType=jsonObj["cwbtool__Type__c"]
    print(str(compParent)+"-"+component+"-"+compType)
    if(compParent):
        if(compParent not in schema):
            print(compParent+" does not exists")
            schema[compParent]=[]
        data = (component,compType)
        schema[compParent].append(data)
        #print (json.dumps(schema))
    else:
        print(component+" does not exists")
        if(component not in schema):
            schema[component]=[]
        #print (json.dumps(schema))
# Out:
# None-Account-Object
# Account does not exists
# Account-Account_Manager__c-Field
# Account-Account_Number__c-Field
# Account-Account_Number_External_ID__c-Field
# Account-AccountNumber-Field
# Account-Servicing__c-Field
# Account-Servicer_UPB_M__c-Field
# Account-Servicer_Rank_Number__c-Field
# Account-Servicer_Rank_Loan_Count__c-Field
# Account-Servicer_Rank_Group__c-Field
# Account-Servicer_Profile__c-Field
# Account-Servicer_Loan_Count__c-Field
# Account-Servicer_Group_Count__c-Field
# Account-Servicer_Family_Number__c-Field
# Account-Servicer_Family_Name__c-Field
# Account-Service_Type__c-Field
# Account-Seller_Family_Number__c-Field
# Account-Seller_Family_Name__c-Field
# Account-Sell_Servicing_Released__c-Field
# Account-SDQ_Rate_Prior_Mth__c-Field
# Account-SDQ_Rate__c-Field
# Account-SDQ_Count__c-Field
# Account-S_S_Type__c-Field
# Account-S_S_Name__c-Field
# Account-S_P_Rating__c-Field
# Account-Rollout_Date_UCDP_DI__c-Field
# Account-Rollout_Date_Servicing__c-Field
# ...

# %%
print(json.dumps(schema))
# Out:
# {"Account": [["Account_Manager__c", "Field"], ["Account_Number__c", "Field"], ["Account_Number_External_ID__c", "Field"], ["AccountNumber", "Field"], ["Servicing__c", "Field"], ["Servicer_UPB_M__c", "Field"], ["Servicer_Rank_Number__c", "Field"], ["Servicer_Rank_Loan_Count__c", "Field"], ["Servicer_Rank_Group__c", "Field"], ["Servicer_Profile__c", "Field"], ["Servicer_Loan_Count__c", "Field"], ["Servicer_Group_Count__c", "Field"], ["Servicer_Family_Number__c", "Field"], ["Servicer_Family_Name__c", "Field"], ["Service_Type__c", "Field"], ["Seller_Family_Number__c", "Field"], ["Seller_Family_Name__c", "Field"], ["Sell_Servicing_Released__c", "Field"], ["SDQ_Rate_Prior_Mth__c", "Field"], ["SDQ_Rate__c", "Field"], ["SDQ_Count__c", "Field"], ["S_S_Type__c", "Field"], ["S_S_Name__c", "Field"], ["S_P_Rating__c", "Field"], ["Rollout_Date_UCDP_DI__c", "Field"], ["Rollout_Date_Servicing__c", "Field"], ["Rollout_Date_Pricing_Execution__c", "Field"], ["Rollout_Date_LQA_S2S__c", "Field"], ["Prici
# ...

# %%
for keyV in schema:
    sqlStr= "create table "+keyV+"("
    columnObj=[]
    for column in schema[keyV]:
        columnObj.append(column[0]+" "+column[1])
    sqlStr=sqlStr+" "+ ",".join(columnObj)+" )"
    print(sqlStr)
# Out:
# create table Account( Account_Manager__c Field,Account_Number__c Field,Account_Number_External_ID__c Field,AccountNumber Field,Servicing__c Field,Servicer_UPB_M__c Field,Servicer_Rank_Number__c Field,Servicer_Rank_Loan_Count__c Field,Servicer_Rank_Group__c Field,Servicer_Profile__c Field,Servicer_Loan_Count__c Field,Servicer_Group_Count__c Field,Servicer_Family_Number__c Field,Servicer_Family_Name__c Field,Service_Type__c Field,Seller_Family_Number__c Field,Seller_Family_Name__c Field,Sell_Servicing_Released__c Field,SDQ_Rate_Prior_Mth__c Field,SDQ_Rate__c Field,SDQ_Count__c Field,S_S_Type__c Field,S_S_Name__c Field,S_P_Rating__c Field,Rollout_Date_UCDP_DI__c Field,Rollout_Date_Servicing__c Field,Rollout_Date_Pricing_Execution__c Field,Rollout_Date_LQA_S2S__c Field,Pricing_Eligibility_PPE_SMA__c Field,Pricing_Eligibility_PPE_Comments__c Field,PPE__c Field,PhotoUrl Field,Phone Field,PE_S2S__c Field,ParentId Field,Ownership_Type__c Field,Ownership_Comments__c Field,Ownership Field,Owne
# ...
